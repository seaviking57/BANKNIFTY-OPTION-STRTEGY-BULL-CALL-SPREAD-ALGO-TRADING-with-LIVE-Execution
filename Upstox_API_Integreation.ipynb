# %% [markdown]
# <a href="https://colab.research.google.com/github/seaviking57/BANKNIFTY-OPTION-STRTEGY-BULL-CALL-SPREAD-ALGO-TRADING-with-LIVE-Execution/blob/main/Upstox_API_Integreation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Authentication of Upstox Account
# Getting User details
# Getting User Profile
# Getting Margin Details
# Out:
# Hello

# %%
client_id = "9829023100"
client_pass = ""
client_pin = ""

api_key = "24f68c20-0457-4034-a7d9-035ca883b405"
api_secret = "k5p4j5i211"

# %%
api_key = "24f68c20-0457-4034-a7d9-035ca883b405"
redirect_uri = "https://www.unofficed.com/"

login_url = (
    "https://api.upstox.com/v2/login/authorization/dialog"
    "?response_type=code"
    "&client_id=" + api_key +
    "&redirect_uri=" + redirect_uri)

login_url
# Out:
# 'https://api.upstox.com/v2/login/authorization/dialog?response_type=code&client_id=24f68c20-0457-4034-a7d9-035ca883b405&redirect_uri=https://www.unofficed.com/'

# %%
import requests

# Define your variables
auth_code = "lVKlVJ"

url = "https://api.upstox.com/v2/login/authorization/token"

# Request headers
headers = {
    "accept": "application/json",
    "Api-Version": "2.0",
    "Content-Type": "application/x-www-form-urlencoded"
}

payload = {
    "code": auth_code,
    "client_id": api_key,
    "client_secret": "k5p4j5i211",
    "redirect_uri": redirect_uri,
    "grant_type": "authorization_code"
}



response = requests.post(url, data=payload, headers=headers)

print("Status Code:", response.status_code)
print("Response JSON:", response.json())
# Out:
# Status Code: 200
# Response JSON: {'email': 'sylcharlesworth@gmail.com', 'exchanges': ['BSE', 'MCX', 'CDS', 'NSE', 'NFO'], 'products': ['OCO', 'D', 'CO', 'I'], 'broker': 'UPSTOX', 'user_id': '189242', 'user_name': 'SYLVESTER CHARLESWORTH', 'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'], 'user_type': 'individual', 'poa': False, 'ddpi': False, 'is_active': True, 'access_token': 'eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiIxODkyNDIiLCJqdGkiOiI2ODEyMzJhOGNiOWRhMDZiZGU2MDExM2EiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6ZmFsc2UsImlhdCI6MTc0NjAyMzA4MCwiaXNzIjoidWRhcGktZ2F0ZXdheS1zZXJ2aWNlIiwiZXhwIjoxNzQ2MDUwNDAwfQ.kxCTLXN1Xq1UNL7werfBOFHG1Crwszi_1kzAd1ho6Fs', 'extended_token': None}

# %%
access_token = response.json().get('access_token')
access_token
# Out:
# 'eyJ0eXAiOiJKV1QiLCJrZXlfaWQiOiJza192MS4wIiwiYWxnIjoiSFMyNTYifQ.eyJzdWIiOiIxODkyNDIiLCJqdGkiOiI2ODEyMzJhOGNiOWRhMDZiZGU2MDExM2EiLCJpc011bHRpQ2xpZW50IjpmYWxzZSwiaXNQbHVzUGxhbiI6ZmFsc2UsImlhdCI6MTc0NjAyMzA4MCwiaXNzIjoidWRhcGktZ2F0ZXdheS1zZXJ2aWNlIiwiZXhwIjoxNzQ2MDUwNDAwfQ.kxCTLXN1Xq1UNL7werfBOFHG1Crwszi_1kzAd1ho6Fs'

# %%
# Get Profile details

import requests

url = "https://api.upstox.com/v2/user/profile"

headers = {
    "Accept": "application/json",
    "Authorization": f"Bearer {access_token}"
}

response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)
print("Response JSON:", response.json())
#print("User Profile Data:", profile_data)
# Out:
# Status Code: 200
# Response JSON: {'status': 'success', 'data': {'email': 'sylcharlesworth@gmail.com', 'exchanges': ['BSE', 'MCX', 'CDS', 'NSE', 'NFO'], 'products': ['OCO', 'D', 'CO', 'I'], 'broker': 'UPSTOX', 'user_id': '189242', 'user_name': 'SYLVESTER CHARLESWORTH', 'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'], 'user_type': 'individual', 'poa': False, 'ddpi': False, 'is_active': True}}

# %%
from pprint import pprint
pprint(response.json())
# Out:
# {'data': {'broker': 'UPSTOX',
#           'ddpi': False,
#           'email': 'sylcharlesworth@gmail.com',
#           'exchanges': ['BSE', 'MCX', 'CDS', 'NSE', 'NFO'],
#           'is_active': True,
#           'order_types': ['MARKET', 'LIMIT', 'SL', 'SL-M'],
#           'poa': False,
#           'products': ['OCO', 'D', 'CO', 'I'],
#           'user_id': '189242',
#           'user_name': 'SYLVESTER CHARLESWORTH',
#           'user_type': 'individual'},
#  'status': 'success'}

# %%
# Get Equity and Commodity Margins

import requests

url = "https://api.upstox.com/v2/user/get-funds-and-margin"

headers = {
    "Accept": "application/json",
    "Authorization": f"Bearer {access_token}"
}

response = requests.get(url, headers=headers)

print("Status Code:", response.status_code)
print("Response JSON:", response.json())
from pprint import pprint
pprint(response.json())
# Out:
# Status Code: 200
# Response JSON: {'status': 'success', 'data': {'commodity': {'used_margin': 0.0, 'payin_amount': 0.0, 'span_margin': 0.0, 'adhoc_margin': 0.0, 'notional_cash': 0.0, 'available_margin': 0.0, 'exposure_margin': 0.0}, 'equity': {'used_margin': 0.0, 'payin_amount': 0.0, 'span_margin': 0.0, 'adhoc_margin': 0.0, 'notional_cash': 0.0, 'available_margin': 0.0, 'exposure_margin': 0.0}}}
# {'data': {'commodity': {'adhoc_margin': 0.0,
#                         'available_margin': 0.0,
#                         'exposure_margin': 0.0,
#                         'notional_cash': 0.0,
#                         'payin_amount': 0.0,
#                         'span_margin': 0.0,
#                         'used_margin': 0.0},
#           'equity': {'adhoc_margin': 0.0,
#                      'available_margin': 0.0,
#                      'exposure_margin': 0.0,
#                      'notional_cash': 0.0,
#                      'payin_amount': 0.0,
# ...

# %%
# Get Open Position status

import requests

url = "https://api.upstox.com/v2/user/portfolio/positions"

headers = {
    "Accept": "application/json",
    "Authorization": f"Bearer {access_token}"
}

response = requests.get(url, headers=headers)

print("Positions Status Code:", response.status_code)
print("Positions Data:", response.json())
#pprint(response.json())
# Out:
# Positions Status Code: 400
# Positions Data: {'status': 'error', 'errors': [{'errorCode': 'UDAPI100012', 'message': 'Invalid Endpoint', 'propertyPath': None, 'invalidValue': None, 'error_code': 'UDAPI100012', 'property_path': None, 'invalid_value': None}]}
